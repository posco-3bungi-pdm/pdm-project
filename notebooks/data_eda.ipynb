# %%
# 관련 라이브러리 임포트
import os
import pandas as pd

# %%
G01 = os.path.join("..", "data", "G-01_정기수리캘린더.csv")
G02 = os.path.join("..", "data", "G-02_조업이벤트.csv")
TCR1 = os.path.join("..", "data", "T-CR1-CAL01_온도.csv")
# Mac, Window 환경은 디렉토리 구분자가 다름.
# os 모듈을 사용해서 path를 join하여 각 운영체제에 맞는 디렉토리 구분자를 만들어냄

# %%
df_repair = pd.read_csv(G01, encoding='utf-8')  # 정기수리 캘린더
df_event = pd.read_csv(G02, encoding='utf-8')  # 조업 이벤트
df_temp = pd.read_csv(TCR1, encoding='utf-8')  # 온도 센서

# %%
print(df_repair.head(5))
print()
print(df_event.head(5))
print()
print(df_temp.head(5))

# %%
print(df_repair.columns)
print()
print(df_event.columns)
print()
print(df_temp.columns)

# %% [markdown]
# ### **df_repair 컬럼명**
# > PLAN_ID: 점검 날짜 계획일? - 장비 계획 고유 ID
# > PLANT_CD: 설비 코드
#     - SP1:  소결로(sinter plant) 1
#     - SP2:  소결로(sinter plant) 1
#     - CR1:  냉간압연제품 생산 라인(Cold Rolled Line) 1
# > START_DT: 정비 시작 일자
#     -
# > END_DT: 정비 종료 일자

# %% [markdown]
# 발표는 10월 26일.
